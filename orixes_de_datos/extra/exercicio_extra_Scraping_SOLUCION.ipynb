# %% [markdown]
# ### Exercicios Extra de Scraping

# %%
# 1. Extrae o prezo do bitcoin mediante scraping da seguinte web
# https://awebanalysis.com/es/coin-details/bitcoin/

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://awebanalysis.com/es/coin-details/bitcoin/'
response = requests.get(url)
soup = BeautifulSoup(response.content,'html.parser')

# %%
#print(soup.prettify())

# %%
result = soup.find('td',{'class': 'wbreak_word align-middle coin_price'})
result.text
# Out:
# '$43,658.75'

# %%
result = soup.find(class_='wbreak_word align-middle coin_price')
result.text
# Out:
# '$43,658.75'

# %%
# 2. Imprime os títulos das entradas da páxina principal de "Menéame"
# https://www.meneame.net/

# %%
headers = { 'User-Agent' : 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0' }
url = 'https://www.meneame.net/'
response = requests.get(url, headers = headers)

# %%
soup = BeautifulSoup(response.content,'html.parser')

# %%
#print(soup.prettify())

# %%
result = soup.find_all('div', {'class':'link-content'})
# result[0]

# %%
result = soup.find_all('class':'link-content'})

# %%
for nova in result:
    print(nova.find('h2').text)
# Out:
# El 40% de los nuevos mossos y bomberos en Catalunya serán mujeres por ley
# CDC: 75% de los muertos por covid-19 en EE UU tenían al menos cuatro comorbilidades
# La entrevista a Carlos Taibo que nunca se emitió
# Sin absolutamente nada que perder, Alberto Garzón declara que los actores españoles no vocalizan
# El candidato de la España Vaciada por Salamanca borra su cuenta de Twitter, que estaba llena de tuits pornográficos
# Enorme ‘dragón marino’ nombrado uno de los mayores hallazgos de fósiles del Reino Unido [ENG]
# La  increíble historia del editor italiano que estafaba a los autores y les robaba sus manuscritos
# El PP borra un tuit de 2018 en el que criticaba las macrogranjas en Castilla-La Mancha
# Serbia advierte a Djokovic que puede enfrentarse  a un castigo si se ha saltado su confinamiento
# Rebotados de Ciudadanos copan 15 puestos de la lista de la España Vaciada por Valladolid
# Usuario de Twitter señala al PP de CLM diez tweets suyos en contra de las macrogranjas y estos los borran al instante
# Un cazador discute de malas maneras con la Guardia Civil
# Las claves de la relación entre población y territorio en España
# Secuencia de acople del Apolo: uniendo el módulo de mando al módulo lunar (eng)
# La Audiencia de Madrid archiva definitivamente la investigación relativa a la Caja de Solidaridad de Podemos
# La historia de como sin comerlo ni beberlo, acabé preso en una carcel de Dubái
# No te fíes de los SMS o llamadas que llegan de BBVA o Santander: los ataques aprovechan el hilo de esos mensajes o tu DNI para engañarte
# Los microbios en las profundidades del océano pueden producir oxígeno sin sol [ENG]
# Alberto Garzón: “Mi posición sobre las macrogranjas será la línea de trabajo de todos los países occidentales”
# Open de Australia 2022: Tomic, a la juez de silla de su partido: "Tengo coronavirus, en dos días doy positivo"
# La EMA se opone a dar dosis de refuerzo «continuamente»
# El periodismo matará la democracia
# Fabricación en Suiza (Genéve). ¿Y si no es verdad?
# Iván Negueruela: “El barco más antiguo del mundo podría desaparecer por errores en su protección”
# El renacimiento digital de tres obras de Klimt destruidas por los nazis

# %%
# 2.1 Crea un dataframe co titular e o nome do medio orixe da noticia (elpais.es, abc.com etc)

# %%
import pandas as pd

# %%
# nova

# %%
# nova.find('a',{'class': 'external-source tm-event'}).text.strip()

# %%
novas = []
for nova in result:
    #print(nova.find('h2').text)
    novas.append([nova.find('h2').text,nova.find('a',{'class': 'external-source tm-event'}).text.strip()])
df_novas = pd.DataFrame(novas,columns = ['titular','enlace'])
df_novas
# Out:
#                                               titular  \
# 0   Almeida: "Almudena Grandes no merece ser Hija ...
# 1   Contra la ideología cripto: descentralización ...
# 2   El Constitucional avala que saldar una deuda c...
# 3   Vox afea un gesto de cortesía de Casado y se e...
# 4             Cuando Ullrich no reconoció a Armstrong
# 5                    Vuelve el ordenador de sobremesa
# 6   Así son Tanxugueiras, el grupo de folclore gal...
# 7   Con el siglo XXI en toda la cara: la experienc...
# 8   Los Simpsons como síntoma de la zombificación ...
# 9   El vicepresidente económico de Vox administró ...
# 10  La jueza que destapó la corrupción en Galicia ...
# 11  Historia de una imagen: La sonriente supervivi...
# 12  Un Congreso de barra libre para las barbaridad...
# 13  José Ángel Morales, neurocientífico: «El enamo...
# 14  41% de positivos en la segunda jornada de crib...
# 15  El "infierno diario" de las personas que sufre...
# 16  La importancia de las copias de seguridad en t...
# 17  Hasta 10.000 euros de sanción por trabajador t...
# 18  La familia de Sara pide al juez que inhabilite...
# 19  La investigación de la presunta caja B del PP ...
# 20  Esta Nochevieja los franceses solo le han pren...
# 21         Calles de Japón en los años cuarenta en 4k
# 22  Generales retirados advierten de que el Ejérci...
# 23  Las excavaciones que se llevan a cabo en Çatal...
# 24  Entra en vigor en la región de Asia-Pacífico e...
#
#                               enlace
# 0                        eldiario.es
# 1                  elsaltodiario.com
# 2                      ultimahora.es
# 3                         publico.es
# 4                         elpais.com
# 5                    enriquedans.com
# 6                 elconfidencial.com
# 7                  valenciaplaza.com
# 8                  elsaltodiario.com
# 9                        eldiario.es
# 10                        publico.es
# 11               elcajondegrisom.com
# 12                       eldiario.es
# 13  lavozdelasalud.lavozdegalicia.es
# 14              elnortedecastilla.es
# 15                       lasexta.com
# 16                         incibe.es
# 17               pymesyautonomos.com
# 18                     elespanol.com
# 19                       eldiario.es
# 20                   edition.cnn.com
# 21                       youtube.com
# 22                      infolibre.es
# 23                terraeantiqvae.com
# 24                      france24.com

# %%
# 3. Imprime os títulos e o ano das películas do Top 250 da IMDB
# https://www.imdb.com/chart/top/

# %%
headers = { 'User-Agent' : 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0' }
url = 'https://www.imdb.com/chart/top/'
response = requests.get(url, headers = headers)
soup = BeautifulSoup(response.content,'html.parser')

# %%
result = soup.find_all('td', {'class':'titleColumn'})

# %%
len(result)
# Out:
# 250

# %%
#result[0]

# %%
for peli in result:
    print(peli.a.text,peli.span.text)
# Out:
# Cadena perpetua (1994)
# El padrino (1972)
# El padrino: Parte II (1974)
# El caballero oscuro (2008)
# 12 hombres sin piedad (1957)
# La lista de Schindler (1993)
# El señor de los anillos: El retorno del rey (2003)
# Pulp Fiction (1994)
# El bueno, el feo y el malo (1966)
# El señor de los anillos: La comunidad del anillo (2001)
# El club de la lucha (1999)
# Forrest Gump (1994)
# Origen (2010)
# El señor de los anillos: Las dos torres (2002)
# El Imperio contraataca (1980)
# Spider-Man: No Way Home (2021)
# Matrix (1999)
# Uno de los nuestros (1990)
# Alguien voló sobre el nido del cuco (1975)
# Los siete samuráis (1954)
# Seven (1995)
# El silencio de los corderos (1991)
# ¡Qué bello es vivir! (1946)
# Ciudad de Dios (2002)
# La vida es bella (1997)
# Salvar al soldado Ryan (1998)
# La guerra de las galaxias (1977)
# Interstellar (2014)
# El viaje de Chihiro (2001)
# La milla verde (1999)
# Parásitos (2019)
# El profesional (Léon) (1994)
# Harakiri (1962)
# El pianista (2002)
# Shutter Island (2010)
# Lock & Stock (1998)
# No es país para viejos (2007)
# Crimen perfecto (1954)
# La quimera del oro (1925)
# Klaus (2019)
# La cosa (1982)
# Tres anuncios en las afueras (2017)
# El séptimo sello (1957)
# El hombre elefante (1980)
# El sexto sentido (1999)
# El show de Truman (1998)
# Jurassic Park (Parque Jurásico) (1993)
# Fresas salvajes (1957)
# El tercer hombre (1949)
# Memories of Murder (Crónica de un asesino en serie) (2003)
# V de Vendetta (2005)
# Blade Runner (1982)
# Trainspotting (1996)
# Del revés (Inside Out) (2015)
# El puente sobre el río Kwai (1957)
# Fargo (1996)
# Buscando a Nemo (2003)
# Warrior (2011)
# Kill Bill: Volumen 1 (2003)
# Lo que el viento se llevó (1939)
# Cuentos de Tokio (1953)
# La ley del silencio (1954)
# Mi padre y mi hijo (2005)
# Dune (2021)
# Relatos salvajes (2014)
# Stalker (1979)
# Prisioneros (2013)
# El cazador (1978)
# El gran hotel Budapest (2014)
# El maquinista de La General (1926)
# El moderno Sherlock Holmes (1924)
# Persona (1966)
# Gran Torino (2008)
# Z (1969)
# Antes de amanecer (1995)
# Mary and Max (2009)
# Atrápame si puedes (2002)
# Caballero sin espada (1939)
# En el nombre del padre (1993)
# Barry Lyndon (1975)
# Perdida (2014)
# La habitación (2015)
# Hasta el último hombre (2016)
# La pasión de Juana de Arco (1928)
# Andhadhun (2018)
# Le Mans '66 (2019)
# 12 años de esclavitud (2013)
# Ser o no ser (1942)
# El gran Lebowski (1998)
# El club de los poetas muertos (1989)
# Cómo entrenar a tu dragón (2010)
# Ben-Hur (1959)
# Mad Max: Furia en la carretera (2015)
# Sonata de otoño (1978)
# Harry Potter y las Reliquias de la Muerte - Parte 2 (2011)
# Million Dollar Baby (2004)
# La doncella (2016)
# El salario del miedo (1953)
# Cuenta conmigo (1986)
# Network, un mundo implacable (1976)
# Logan (2017)
# El odio (1995)
# La leyenda del indomable (1967)
# Siempre a tu lado (Hachiko) (2009)
# A Silent Voice (2016)
# Los cuatrocientos golpes (1959)
# Gangs of Wasseypur (2012)
# Platoon (1986)
# Spotlight (2015)
# Monstruos, S.A. (2001)
# Rebeca (1940)
# La vida de Brian (1979)
# Deseando amar (2000)
# Hotel Rwanda (2004)
# Eskiya (1996)
# Rush (2013)
# Hacia rutas salvajes (2007)
# Rocky (1976)
# Amores perros (2000)
# Nausicaä del Valle del Viento (1984)
# Sucedió una noche (1934)
# Fanny y Alexander (1982)
# Antes del atardecer (2004)
# Andrei Rublev (1966)
# Neon Genesis Evangelion: The End of Evangelion (1997)
# La batalla de Argel (1966)
# Las noches de Cabiria (1957)
# La princesa prometida (1987)
# Paris, Texas (1984)
# Drishyam (2013)

# %%
# 3.2 Crea un dataframe cos datos obtidos

# %%
import pandas as pd

# %%
pelis = []
for peli in result:
    #print(peli.a.text,peli.span.text)
    pelis.append([peli.a.text,peli.span.text.strip('(,)')])
df_pelis = pd.DataFrame(pelis,columns = ['título','ano'])
df_pelis
# Out:
#                     título   ano
# 0          Cadena perpetua  1994
# 1               El padrino  1972
# 2     El padrino: Parte II  1974
# 3      El caballero oscuro  2008
# 4    12 hombres sin piedad  1957
# ..                     ...   ...
# 245    La batalla de Argel  1966
# 246  Las noches de Cabiria  1957
# 247  La princesa prometida  1987
# 248           Paris, Texas  1984
# 249               Drishyam  2013
#
# [250 rows x 2 columns]
