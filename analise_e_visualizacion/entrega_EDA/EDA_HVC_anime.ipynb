# %% [markdown]
# <h1><b><u>Análise exploratorio dos datos Héctor Vilar</u></b></h1>

# %% [markdown]
# <h2><b>Descrición dos datos</b></h2>
# <p><b>Rank:</b> posición dentro do ranking que ocupa o anime</p>
# <p><b>Name:</b> nome do anime</p>
# <p><b>Japanese_name:</b> nome xaponés do anime</p>
# <p><b>Type:</b> tipo do anime(serie, película, ova ...)</p>
# <p><b>Episodes:</b> número de episodios que ten o anime</p>
# <p><b>Studio:</b> estudio que animou o anime</p>
# <p><b>Release_season:</b> temporada(época do ano) na que saíu o anime</p>
# <p><b>Tags:</b> xéneros que abarca o anime</p>
# <p><b>Rating:</b> valoración do anime de 0 a 5</p>
# <p><b>Release_year:</b> ano no que saíu o anime</p>
# <p><b>End_year:</b> ano no que rematou o anime</p>
# <p><b>Description:</b> descripción do anime</p>
# <p><b>Content warning:</b> contido 'perigoso' que pode ter o anime(violencia,suicidio ...)</p>
# <p><b>Related_manga:</b> mangas relacionados</p>
# <p><b>Related_anime:</b> animes relacionados</p>
# <p><b>Voice_actor:</b> persoas que puxeron a voz dos personaxes</p>
# <p><b>Staff:</b> persoas que participaron na realización do anime</p>

# %% [markdown]
# <h2><b>Tipos dos datos</b></h2>
# <p><b>Rank:</b> int</p>
# <p><b>Name:</b> String</p>
# <p><b>Japanese_name:</b> String</p>
# <p><b>Type:</b> String</p>
# <p><b>Episodes:</b> int</p>
# <p><b>Studio:</b> String</p>
# <p><b>Release_season:</b> String</p>
# <p><b>Tags:</b> String</p>
# <p><b>Rating:</b> Float</p>
# <p><b>Release_year:</b> int</p>
# <p><b>End_year:</b> int</p>
# <p><b>Description:</b> String</p>
# <p><b>Content warning:</b> String</p>
# <p><b>Related_manga:</b> String</p>
# <p><b>Related_anime:</b> String</p>
# <p><b>Voice_actor:</b> String</p>
# <p><b>Staff:</b> String</p>

# %%
#Importo as librerías
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Abro o ficheiro obtido de https://www.kaggle.com/vishalmane10/anime-dataset-2022?select=Anime.csv
anime = pd.read_csv('Anime.csv', index_col = 0);

# %%
#Tipo de datos do dataset no dataframe
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18495 entries, 1 to 18495
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             18495 non-null  object
#  1   Japanese_name    7938 non-null   object
#  2   Type             18495 non-null  object
#  3   Episodes         9501 non-null   float64
#  4   Studio           12018 non-null  object
#  5   Release_season   4116 non-null   object
#  6   Tags             18095 non-null  object
#  7   Rating           15364 non-null  float64
#  8   Release_year     18112 non-null  float64
#  9   End_year         2854 non-null   float64
#  10  Description      18491 non-null  object
#  11  Content_Warning  1840 non-null   object
#  12  Related_Mange    7627 non-null   object
#  13  Related_anime    10063 non-null  object
#  14  Voice_actors     15309 non-null  object
#  15  staff            13005 non-null  object
# dtypes: float64(4), object(12)
# memory usage: 2.4+ MB

# %%
#Exemplos do dataset
anime.sample(6)
# Out:
#                                                     Name  \
# Rank
# 7747   Irresponsible Captain Tylor Music Video Collec...
# 16462                Dump to Mon-chan no Chiisana Bouken
# 967                                           Peace Sign
# 15824                     IDOLiSH7: Third BEAT - Part II
# 14155                                Bottom Biting Bug 3
# 1259                      Beyond the Boundary: Shinonome
#
#                                          Japanese_name   Type  Episodes  \
# Rank
# 7747    Musekinin Kanchou Tylor Music Video Collection  Music       NaN
# 16462                                              NaN  OVA         1.0
# 967       My Hero Academia x Kenshi Yonezu: Peace Sign  Music       NaN
# 15824                                              NaN  TV          NaN
# 14155                            Oshiri Kajiri Mushi 3  TV         10.0
# 1259                      Kyoukai no Kanata: Shinonome  DVD S       NaN
#
#                 Studio Release_season  \
# Rank
# 7747               NaN            NaN
# 16462              NaN            NaN
# 967              Bones            NaN
# 15824           TROYCA            NaN
# 14155    Kinema Citrus          Fall
# 1259   Kyoto Animation            NaN
#
#                                                     Tags  Rating  \
# Rank
# 7747   Comedy, Sci Fi, Aliens, Military, Outer Space,...    3.35
# 16462  Animal Protagonists, Educational, Family Frien...     NaN
# 967                     Action, Superheroes, Superpowers    3.98
# 15824  Drama, Idols, Music, Showbiz, Based on a Mobil...     NaN
# 14155  Comedy, Animal Protagonists, Anthropomorphic, ...    2.81
# 1259   Action, Fantasy, Contemporary Fantasy, Magic, ...    3.92
#
#        Release_year  End_year  \
# Rank
# 7747         1994.0       NaN
# 16462        1977.0       NaN
# 967          2017.0       NaN
# 15824        2022.0       NaN
# 14155        2014.0       NaN
# 1259         2014.0       NaN
#
#                                              Description Content_Warning  \
# Rank
# 7747                'No synopsis yet - check back soon!'             NaN
# 16462                 No synopsis yet - check back soon!             NaN
# 967    'Meet the super-powered students of\xa0U.A. Hi...             NaN
# 15824              Continuation of IDOLiSH7: Third BEAT!             NaN
# 14155                 Third season of Bottom Biting Bug.             NaN
# 1259   'Two years ago, the Nase siblings met Akihito ...        Violence
#
#                          Related_Mange  \
# Rank
# 7747                               NaN
# 16462                              NaN
# 967                   My Hero Academia
# 15824                              NaN
# 14155                              NaN
# 1259   Kyoukai no Kanata (Light Novel)
#
#                                            Related_anime  \
# Rank
# 7747   Irresponsible Captain Tylor, Irresponsible Cap...
# 16462                                                NaN
# 967                                   My Hero Academia 2
# 15824                              IDOLiSH7: Third BEAT!
# 14155  Bottom Biting Bug, Bottom Biting Bug 2, Bottom...
# 1259   Beyond the Boundary, Beyond the Boundary: Idol...
#
#                                             Voice_actors  \
# Rank
# 7747   Kouji Sawai\nDirector, Kouichi Mashimo\nDirect...
# 16462                                                NaN
# 967    Izuku Midoriya, Katsuki Bakugo, Ochaco Uraraka...
# 15824                                                NaN
# 14155  Bottom Biting Bug : Tomoko Kaneda, Bottom Biti...
# 1259   Akihito Kanbara : Kenn, Hiroomi Nase : Tatsuhi...
#
#                                                    staff
# Rank
# 7747   Kouji Sawai : Director, Kouichi Mashimo : Dire...
# 16462                                                NaN
# 967    Kouhei Horikoshi : Original Creator, Kenji Nag...
# 15824                                                NaN
# 14155  Masatsugu Arakawa : Director, Masayuki Kojima ...
# 1259                                                 NaN

# %%
#Resumo variables numéricas
anime.describe()
#Pódese ver que hai algún outlier claro dentro do número de episodios dos animes
# Out:
#           Episodes        Rating  Release_year     End_year
# count  9501.000000  15364.000000  18112.000000  2854.000000
# mean     20.920850      3.355133   2006.520318  2004.256132
# std      37.990858      0.400624     15.189537    13.257484
# min       1.000000      0.960000   1907.000000  1962.000000
# 25%       2.000000      3.130000   2001.000000  1996.000000
# 50%      12.000000      3.360000   2012.000000  2007.000000
# 75%      26.000000      3.590000   2017.000000  2015.000000
# max     800.000000      4.600000   2023.000000  2022.000000

# %%
#Resumo variables categóricas
anime.describe(include='object')
#Con isto pódese apreciar que type e release_season posúen valores poucos valores diferentes
# Out:
#                      Name Japanese_name   Type          Studio Release_season  \
# count               18495          7938  18495           12018           4116
# unique              18443          7902      8             745              4
# top     [email protected]           The  TV     Toei Animation         Spring
# freq                    4            14   5446             737           1291
#
#             Tags                         Description Content_Warning  \
# count      18095                               18491            1840
# unique     11799                               10012             208
# top     Vocaloid  No synopsis yet - check back soon!        Violence
# freq         395                                4579             529
#
#                                             Related_Mange Related_anime  \
# count                                                7627         10063
# unique                                               4151          9451
# top     Crayon Shin-chan, Shin Crayon Shin-chan, Crayo...     One Piece
# freq                                                   33            35
#
#                    Voice_actors                   staff
# count                     15309                   13005
# unique                    13615                   10559
# top     Taku Furukawa\nDirector  Pinocchio-P : Producer
# freq                         42                      45

# %%
#Tamaño do dataset
anime.shape
# Out:
# (18495, 16)

# %%
# Listar todas as columnas
columns = list(anime.columns)
columns
# Out:
# ['Name',
#  'Japanese_name',
#  'Type',
#  'Episodes',
#  'Studio',
#  'Release_season',
#  'Tags',
#  'Rating',
#  'Release_year',
#  'End_year',
#  'Description',
#  'Content_Warning',
#  'Related_Mange',
#  'Related_anime',
#  'Voice_actors',
#  'staff']

# %%
# Creamos dúas listas diferentes:
# - nomes das columnas categóricas
# - nomes das columnas numéricas 
# Isto facilitará o tratamento das diferentes variables por separado

cats = list(anime.select_dtypes(include=['object']).columns)
nums = list(anime.select_dtypes(exclude=['object']).columns)
print(f'Variables categóricas: {cats}')
print(f'Variables numéricas: {nums}')
# Out:
# Variables categóricas: ['Name', 'Japanese_name', 'Type', 'Studio', 'Release_season', 'Tags', 'Description', 'Content_Warning', 'Related_Mange', 'Related_anime', 'Voice_actors', 'staff']
# Variables numéricas: ['Episodes', 'Rating', 'Release_year', 'End_year']

# %%
# Consultamos o número de valores diferentes en cada columna
anime.nunique(axis=0)
# Out:
# Name               18443
# Japanese_name       7902
# Type                   8
# Episodes             205
# Studio               745
# Release_season         4
# Tags               11799
# Rating               289
# Release_year         103
# End_year              60
# Description        10012
# Content_Warning      208
# Related_Mange       4151
# Related_anime       9451
# Voice_actors       13615
# staff              10559
# dtype: int64

# %%
# búsqueda de nans - TRATAMENTO DE MISSING VALUES
anime.isna().sum()
# Out:
# Name                   0
# Japanese_name      10557
# Type                   0
# Episodes            8994
# Studio              6477
# Release_season     14379
# Tags                 400
# Rating              3131
# Release_year         383
# End_year           15641
# Description            4
# Content_Warning    16655
# Related_Mange      10868
# Related_anime       8432
# Voice_actors        3186
# staff               5490
# dtype: int64

# %%
# proporción de nans
print('Porcentaxe nulos Japanese_name: {}%'.format(10557/len(anime)))
print('Porcentaxe nulos Episodes: {}%'.format(8994/len(anime)))
print('Porcentaxe nulos Studio: {}%'.format(6477/len(anime)))
print('Porcentaxe nulos Release_season: {}%'.format(14379/len(anime)))
print('Porcentaxe nulos Tags: {}%'.format(400/len(anime)))
print('Porcentaxe nulos Rating: {}%'.format(3131/len(anime)))
print('Porcentaxe nulos Release_year: {}%'.format(383/len(anime)))
print('Porcentaxe nulos End_year: {}%'.format(15641/len(anime)))
print('Porcentaxe nulos Description: {}%'.format(4/len(anime)))
print('Porcentaxe nulos Content_Warning: {}%'.format(16655/len(anime)))
print('Porcentaxe nulos Related_Mange: {}%'.format(10868/len(anime)))
print('Porcentaxe nulos Related_anime: {}%'.format(8432/len(anime)))
print('Porcentaxe nulos Voice_actors: {}%'.format(3186/len(anime)))
print('Porcentaxe nulos Staff: {}%'.format(5490/len(anime)))
# Out:
# Porcentaxe nulos Japanese_name: 0.5708029197080292%
# Porcentaxe nulos Episodes: 0.48629359286293594%
# Porcentaxe nulos Studio: 0.35020275750202756%
# Porcentaxe nulos Release_season: 0.7774533657745336%
# Porcentaxe nulos Tags: 0.021627466882941336%
# Porcentaxe nulos Rating: 0.1692889970262233%
# Porcentaxe nulos Release_year: 0.02070829954041633%
# Porcentaxe nulos End_year: 0.8456880237902136%
# Porcentaxe nulos Description: 0.00021627466882941334%
# Porcentaxe nulos Content_Warning: 0.9005136523384698%
# Porcentaxe nulos Related_Mange: 0.587618275209516%
# Porcentaxe nulos Related_anime: 0.45590700189240335%
# Porcentaxe nulos Voice_actors: 0.17226277372262774%
# Porcentaxe nulos Staff: 0.29683698296836986%

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18495 entries, 1 to 18495
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             18495 non-null  object
#  1   Japanese_name    7938 non-null   object
#  2   Type             18495 non-null  object
#  3   Episodes         9501 non-null   float64
#  4   Studio           12018 non-null  object
#  5   Release_season   4116 non-null   object
#  6   Tags             18095 non-null  object
#  7   Rating           15364 non-null  float64
#  8   Release_year     18112 non-null  float64
#  9   End_year         2854 non-null   float64
#  10  Description      18491 non-null  object
#  11  Content_Warning  1840 non-null   object
#  12  Related_Mange    7627 non-null   object
#  13  Related_anime    10063 non-null  object
#  14  Voice_actors     15309 non-null  object
#  15  staff            13005 non-null  object
# dtypes: float64(4), object(12)
# memory usage: 2.4+ MB

# %%
#Elimino as columnas con un porcentaxe superior ao 50 % de nulos ademais da columna Related_anime que non ten demasiada importancia, ao igual que a columna Voice_actors
anime = anime.dropna(axis=1,thresh=(len(anime)/2))
anime = anime.drop('Related_anime', axis=1)
anime = anime.drop('Voice_actors', axis=1)
anime.shape
# Out:
# (18495, 9)

# %%
#Trato individualmente las otras columnas
#Elimino algún espazos que hai no tipo
anime.Type = anime.Type.apply(lambda x: x.strip())
anime['Description'] = anime[['Description']].apply(lambda x: x.fillna('ningunha'),axis=0)
anime['Release_year'] = anime[['Release_year']].apply(lambda x: x.fillna(x.mean()),axis=0)
anime['Tags'] = anime[['Tags']].apply(lambda x: x.fillna('descoñecido'),axis=0)

anime.isna().sum()
# Out:
# Name               0
# Type               0
# Episodes        8990
# Studio          6469
# Tags               0
# Rating          3131
# Release_year       0
# Description        0
# staff           5482
# dtype: int64

# %%
# Buscar filas duplicadas
print(f'Total de filas duplicadas: {anime.duplicated().sum()}')
# Out:
# Total de filas duplicadas: 14

# %%
#Borramos as filas duplicadas
anime.drop_duplicates(inplace=True)
anime.shape
# Out:
# (18481, 9)

# %%
#O resto de nulos deixoos e gardoo unha copia
anime.to_csv('anime_limpo.csv',index=False)

# %%
#VISUALIZACIÓN
sns.displot(anime.Rating, height=7,kde=True)
plt.title("Distribución de la valoración", size=18);
#A maioría dos animes teñen unha valoración comprendida entre 3 e 4 puntos, moi poucos consiguen unha puntuación maior e al menos
# neste dataset ningún anime recibe a valoración más alta(5), tamén apréciase que moi poucos animes reciben unha valoración excesivamente baixa

# %%
sns.histplot(anime.Release_year, color="red", kde=True)
plt.title('Distribución de su año de salida', size=18);
#Neste gráfico e tendo en conta que apliquei aa media para sustituir os valores nulos deste campo
#apréciase que a produción dos anime tivo un gran auxe a partir do 1980, alcanzando un gran pico entorno ao 2012 e que a día de hoxe segue
#mantendo un nivel alto, ademáis vense que os primeros animes surxiron a principios do 1900, hace 100 anos

# %%
sns.displot(anime.Episodes, height=10, color="black")
plt.title('Distribución del número de episodios', size=18);
#Pódese apreciar que os animes que máis destacan son os cortos, cunha cantidade de episodios comprendida principalmente entre os 12 e 24
#Ademáis apréciase que os animes con máis de 100 episodios vólvense moi escasos, e vanse facendo máis escasos conforme acadan un número de episodios elevados

# %%
#Esta é a forma das distribucións do tipo de anime
plt.figure(figsize=(15,15))
sns.barplot(y=anime['Type'], x=anime['Type'].index, ci=None)
plt.title('Distribution of {}'.format('Type'), size=20)
plt.show()
#Apréciase que maioritariamente os animes ocupan diversos formatos, poden ser sacados en internet ao mesmo tempo
#que se emiten por televisión ou se distribúen mediante dvds, aínda que non comprendo o porque de na forma de distribución se inclúe o 'tipo de contenido' (movie, music, OVA)

# %%
plt.title('Influencia do tipo de anime e a valoración', size=20)
sns.boxplot(x=anime.Type, y=anime.Rating, palette='rainbow');

# %%
top_studios = anime.Studio.value_counts()[:15]
sns.barplot(y=top_studios.index, x=top_studios, ci=False)
plt.title('Estudios de anime con su respectivas cantidades', size=20);
#O estudo que máis animes produciu foi TOEI Animation por unha gran diferenza

# %%
studios_more_20 = list(anime.Studio.value_counts().index[:111]) #Os 111 primeiros estudos animaron mínimo 20 animes
top_studios_rtg = anime[anime.Studio.isin(studios_more_20)].groupby('Studio').Rating.mean().sort_values(ascending=False)[:15]
plt.figure(figsize=(15,15))
sns.barplot(y=top_studios_rtg.index, x=top_studios_rtg.values).set_title('Valoración dos mellores estudios que posúen máis de 20 animes', size=20);

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18481 entries, 1 to 18495
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          18481 non-null  object
#  1   Type          18481 non-null  object
#  2   Episodes      9491 non-null   float64
#  3   Studio        12012 non-null  object
#  4   Tags          18481 non-null  object
#  5   Rating        15350 non-null  float64
#  6   Release_year  18481 non-null  float64
#  7   Description   18481 non-null  object
#  8   staff         12999 non-null  object
# dtypes: float64(3), object(6)
# memory usage: 1.9+ MB

# %%
sns.relplot(x='Release_year', y='Rating', data=anime)
plt.show()
#Con este gráfico aínda que non se visualiza moi ben pola gran cantidade de datos, apréciase que os animes mellor e peor valorados datan das fechas actuais(ademáis de ver a concentración destes nos últimos anos)

# %%
#correlacion variables numéricas
#cats= ['Name', 'Type', 'Studio', 'Tags', 'Rating', 'Release_year', 'Description', 'staff']
sns.heatmap(data=anime.corr(), annot=True, fmt='0.3f', cmap='cividis');
#Apréciase que hai unha mala correlación

# %%
# %pip install wordcloud
from wordcloud import WordCloud
all_text = ''.join([desc for desc in list(anime.Description) if isinstance(desc, str)])
wordcloud = WordCloud(background_color='white').generate(all_text)
plt.figure(figsize=(14,12))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
#Vin isto nun exemplo en kaggle e pareceume chulo incluir unha nube coas palabras das descripción
# Out:
# Requirement already satisfied: wordcloud in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (1.8.1)
# Requirement already satisfied: matplotlib in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (from wordcloud) (3.5.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (from wordcloud) (1.20.3)
# Requirement already satisfied: pillow in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (from matplotlib->wordcloud) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\hector.vilarcarpente\anaconda3\envs\sistemasbigdata\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Conclusións:
#O anime leva en auxe dende o século pasado, cada vez son máis a cantidade de animes que hai e os cales podes obter ou visualizar
#nunha gran cantidade de formatos. Ademáis aínda que a cantidade de empresas de animación é abrumadora, hai algunhas as cales concentran
#a gran maioría da produción e distribución destos animes, os cales maioritariamente alcanzan unha valoración superior ao aprobado e que moi poucos
#reciben unha valoración mala, ademáis de que ningún posúe unha valoración perfecta(al menos neste dataset)
